# %% [markdown]
# # 02 - Preprocessing
#
# Clean and standardize raw data using `src/preprocessing.py`.

# %%
import sys
sys.path.append('../src')
from preprocessing import clean_dataset

# column_map = {'Time_s': 'time_s', 'Temp_C': 'temperature_c', 'O2_pct': 'o2_pct'}
# clean_dataset('../data/raw/experiment_001.csv', column_map, '../data/processed/experiment_001_clean.csv')

# %% [markdown]
# ## Sanity check the cleaned output

# %%
# clean = pd.read_csv('../data/processed/experiment_001_clean.csv')
# clean.isna().sum()
