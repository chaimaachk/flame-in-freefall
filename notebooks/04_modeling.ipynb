# %% [markdown]
# # 04 - Modeling
#
# Train and evaluate the risk prediction model using `src/model.py`.

# %%
import sys, pandas as pd
sys.path.append('../src')
from model import prepare_xy, train_model, save_model, predict_risk_score

# feature_table = pd.read_csv('../data/processed/feature_table.csv')
# X, y = prepare_xy(feature_table)
# clf = train_model(X, y)
# save_model(clf, '../src/model.joblib')

# %% [markdown]
# ## Try the risk engine end-to-end

# %%
import sys
sys.path.append('../src')
from risk_engine import evaluate_risk

# score = predict_risk_score(clf, X.iloc[0].to_dict())
# decision = evaluate_risk(score)
# print(decision)
