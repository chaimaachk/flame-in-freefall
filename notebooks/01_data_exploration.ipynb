# %% [markdown]
# # 01 - Data Exploration
#
# Initial look at the raw microgravity combustion dataset(s).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# TODO: point to actual raw file once dataset is confirmed
# df = pd.read_csv('../data/raw/experiment_001.csv')
# df.head()

# %% [markdown]
# ## Inspect structure

# %%
# df.info()
# df.describe()

# %% [markdown]
# ## Plot raw sensor traces
#
# Look at temperature, O2%, and heat flux over time to identify combustion phases (ignition, growth, peak, decay).

# %%
# fig, ax = plt.subplots(figsize=(10,4))
# ax.plot(df['time_s'], df['temperature_c'])
# ax.set_xlabel('time (s)'); ax.set_ylabel('temperature (C)')
# plt.savefig('../figures/raw_temperature_trace.png')
